# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#carregando os dados em um data frame

df = pd.read_csv('/content/vendas_sorvete.csv')

# %%
#separando as variaveis

temperatura = df[['Temperatura (°C)']]
vendas = df['Vendas de Sorvete']

# %%
#criando o modelo

modelo = LinearRegression()
modelo.fit(temperatura, vendas)
# Out:
# LinearRegression()

# %%
#verificando os coeficientes do modelo

print("Coeficiente angular: {}".format(modelo.coef_[0]))
print("Coeficiente linear: {}".format(modelo.intercept_))
# Out:
# Coeficiente angular: 2.9841095447850505
# Coeficiente linear: 1.086917364518996

# %%
#visualizando a regressão

plt.scatter(temperatura, vendas, color="blue", label="Dados reais")
plt.plot(temperatura, modelo.predict(temperatura), color="red", label="Regressão linear")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Vendas de Sorvete")
plt.legend()
plt.title("Relação entre Temperatura e Vendas de Sorvete")
plt.show()

# %%
#testando uma previsão

modelo.predict([[30.5]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92.10225848])
